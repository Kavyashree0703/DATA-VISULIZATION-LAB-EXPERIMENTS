# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("START-UMD/gtd")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 28.7M/28.7M [00:00<00:00, 83.6MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/START-UMD/gtd/versions/3

# %%
import os
import pandas as pd

print("Dataset path:", path)

print("\nFiles in dataset:")
print(os.listdir(path))

# Find CSV file automatically
csv_file = [f for f in os.listdir(path) if f.endswith(".csv")][0]

print("\nCSV file:", csv_file)

# Load dataset
df = pd.read_csv(
    os.path.join(path, csv_file),
    encoding="latin1",
    low_memory=False
)

print("\nFirst 5 rows:")
display(df.head())

print("\nLast 5 rows:")
display(df.tail())

print("\nDataset information:")
df.info()

print("\nShape:")
print(df.shape)

print("\nColumns:")
print(df.columns.tolist())

print("\nData types:")
print(df.dtypes)

print("\nStatistical description:")
display(df.describe())

print("\nMissing values:")
display(df.isnull().sum())

print("\nTop 10 countries:")
display(df["country_txt"].value_counts().head(10))

print("\nRegions:")
display(df["region_txt"].value_counts())

print("\nAttack types:")
display(df["attacktype1_txt"].value_counts())

print("\nUnique attack types:")
print(df["attacktype1_txt"].unique())

print("\nCorrelation:")
display(df.corr(numeric_only=True))

# Excel
df.to_excel("terrorism_data.xlsx", index=False)

# JSON
df.to_json("terrorism_data.json", orient="records", indent=4)

# CSV
df.to_csv("terrorism_data.csv", index=False)

print("\nCSV, Excel and JSON files created successfully.")
# Out:
# Dataset path: /root/.cache/kagglehub/datasets/START-UMD/gtd/versions/3
#
# Files in dataset:
# ['globalterrorismdb_0718dist.csv']
#
# CSV file: globalterrorismdb_0718dist.csv
#
# First 5 rows:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# ...
